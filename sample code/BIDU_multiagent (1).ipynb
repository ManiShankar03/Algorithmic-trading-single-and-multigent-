# %%
#multiagent ppo
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment for Training
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.entry_price = 0
        self.trades = []
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)
        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, **kwargs):
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']
        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:  # Close short
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0
        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:  # Close long
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Mixed Multi-Agent Testing Environment
class MixedMultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(MixedMultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.scaler = scaler

        # Two teams with two agents each
        self.num_teams = 2
        self.agents_per_team = 2
        self.num_agents = self.num_teams * self.agents_per_team

        # Initialize agent balances, positions, and trades
        self.balances = [initial_balance] * self.num_agents
        self.positions = [0] * self.num_agents
        self.entry_prices = [0] * self.num_agents
        self.trades = [[] for _ in range(self.num_agents)]

    def reset(self, **kwargs):
        self.current_step = 0
        self.balances = [self.initial_balance] * self.num_agents
        self.positions = [0] * self.num_agents
        self.entry_prices = [0] * self.num_agents
        self.trades = [[] for _ in range(self.num_agents)]
        return [self._get_observation() for _ in range(self.num_agents)], {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, actions):
        rewards = [0] * self.num_agents
        current_price = self.data.iloc[self.current_step]['close']
        for i, action in enumerate(actions):
            if action == 1:  # Buy
                if self.positions[i] == 0:
                    self.positions[i] = 1
                    self.entry_prices[i] = current_price
                elif self.positions[i] == -1:  # Close short
                    reward = self.entry_prices[i] - current_price
                    self.balances[i] += reward
                    rewards[i] = reward
                    self.positions[i] = 0
                    self.trades[i].append(reward)
            elif action == 2:  # Sell
                if self.positions[i] == 0:
                    self.positions[i] = -1
                    self.entry_prices[i] = current_price
                elif self.positions[i] == 1:  # Close long
                    reward = current_price - self.entry_prices[i]
                    self.balances[i] += reward
                    rewards[i] = reward
                    self.positions[i] = 0
                    self.trades[i].append(reward)

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return [self._get_observation() for _ in range(self.num_agents)], rewards, terminated, truncated, {}

# Calculate individual metrics
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = total_profit / initial_balance
    
    # Calculate positive and negative trades for profit factor
    positive_trades = [trade for trade in trades if trade > 0]
    negative_trades = [trade for trade in trades if trade < 0]
    profit_factor = sum(positive_trades) / abs(sum(negative_trades)) if negative_trades else float('inf')

    win_rate = len(positive_trades) / len(trades) if trades else 0

    # Calculate Sharpe Ratio
    sharpe_ratio = np.mean(trades) / np.std(trades) if np.std(trades) != 0 else 0

    # Sortino Ratio (uses only negative trades as downside deviation)
    downside_std = np.std([trade for trade in trades if trade < 0])
    sortino_ratio = np.mean(trades) / downside_std if downside_std != 0 else 0

    # Maximum Drawdown
    cumulative_balance = np.cumsum(trades)
    running_max = np.maximum.accumulate(cumulative_balance)
    drawdown = running_max - cumulative_balance
    max_drawdown = np.max(drawdown) if len(drawdown) > 0 else 0

    return {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }

# Sharpe Ratio-weighted aggregation
def aggregate_metrics_sharpe_weighted(metrics_list):
    # Filter out agents with non-positive Sharpe Ratios
    positive_sharpe_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_sharpe_metrics)
    
    # If no agents have a positive Sharpe Ratio, return zeros for all metrics
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_sharpe_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'BIDU_TRAINING.csv'
    test_file = 'BIDU_TESTING.csv'
    df_train_normalized, df_test_normalized, scaler = load_and_normalize_data(train_file, test_file)

    # Track training metrics
    training_metrics = []

    # Train each agent independently in single-agent environments
    models = []
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train_normalized, window_size=10, scaler=scaler)
        model = PPO("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=50000)
        models.append(model)

        # Calculate training metrics for each agent
        final_balance = env_train.balance
        metrics = calculate_metrics(env_train.trades, env_train.initial_balance, final_balance)
        training_metrics.append(metrics)
        print(f"\n--- Agent {i+1} Training Metrics ---")
        for metric, value in metrics.items():
            print(f"{metric}: {value}")

    # Aggregate training metrics with Sharpe Ratio weighting
    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics for All Agents (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the mixed multi-agent environment
    env_test = MixedMultiAgentEnv(df_test_normalized, window_size=10, scaler=scaler)
    obs, _ = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics for each agent in the testing environment
    testing_metrics = []
    for i in range(4):  # 4 agents
        final_balance = env_test.balances[i]
        metrics = calculate_metrics(env_test.trades[i], env_test.initial_balance, final_balance)
        testing_metrics.append(metrics)
        print(f"\n--- Agent {i+1} Testing Metrics ---")
        for metric, value in metrics.items():
            print(f"{metric}: {value}")

    # Aggregate testing metrics with Sharpe Ratio weighting
    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics for All Agents (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 2352 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1831         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0077598887 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -4.15        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0201       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 0.00624      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1726        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016550932 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00509    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00862    |
# |    value_loss           | 0.00755     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 4.8          |
# | time/                   |              |
# |    fps                  | 1679         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0047662724 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.509        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0187      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 0.0118       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 4.8         |
# | time/                   |             |
# |    fps                  | 1646        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010740558 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0136     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0062     |
# |    value_loss           | 0.00434     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 4.8         |
# | time/                   |             |
# |    fps                  | 1628        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.003267491 |
# |    clip_fraction        | 0.046       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.984      |
# |    explained_variance   | -0.0884     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000609   |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00473    |
# |    value_loss           | 0.00228     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 4.8          |
# | time/                   |              |
# |    fps                  | 1604         |
# |    iterations           | 7            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0063249366 |
# |    clip_fraction        | 0.0476       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.566        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0131       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.012       |
# |    value_loss           | 0.0141       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 5.98        |
# | time/                   |             |
# |    fps                  | 1594        |
# |    iterations           | 8           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010313816 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0222      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 0.00315     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 5.98        |
# | time/                   |             |
# |    fps                  | 1562        |
# |    iterations           | 9           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006493575 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.492       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0191     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00742    |
# |    value_loss           | 0.00327     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 5.98         |
# | time/                   |              |
# |    fps                  | 1553         |
# |    iterations           | 10           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0045350296 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.0568       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00695     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00602     |
# |    value_loss           | 0.00173      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 5.98        |
# | time/                   |             |
# |    fps                  | 1550        |
# |    iterations           | 11          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008861112 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | -0.114      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0208     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 0.0143      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 8.78         |
# | time/                   |              |
# |    fps                  | 1549         |
# |    iterations           | 12           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0066260193 |
# |    clip_fraction        | 0.0447       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.0679      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0353      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00948     |
# |    value_loss           | 0.00376      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 8.78         |
# | time/                   |              |
# |    fps                  | 1543         |
# |    iterations           | 13           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0067851716 |
# |    clip_fraction        | 0.0762       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.25        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0136      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00761     |
# |    value_loss           | 0.00198      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 8.78         |
# | time/                   |              |
# |    fps                  | 1541         |
# |    iterations           | 14           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0068986476 |
# |    clip_fraction        | 0.0682       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.0611       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0283      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0118      |
# |    value_loss           | 0.00416      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 13           |
# | time/                   |              |
# |    fps                  | 1541         |
# |    iterations           | 15           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0074996245 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.875       |
# |    explained_variance   | 0.098        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0113      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00827     |
# |    value_loss           | 0.0225       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 13          |
# | time/                   |             |
# |    fps                  | 1539        |
# |    iterations           | 16          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007887725 |
# |    clip_fraction        | 0.0883      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | -0.333      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0103     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 0.00383     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 13          |
# | time/                   |             |
# |    fps                  | 1540        |
# |    iterations           | 17          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007924546 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | -0.00743    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0121     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00892    |
# |    value_loss           | 0.00276     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 13          |
# | time/                   |             |
# |    fps                  | 1521        |
# |    iterations           | 18          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006832597 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.872      |
# |    explained_variance   | 0.518       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0124     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 0.0117      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 17.8        |
# | time/                   |             |
# |    fps                  | 1522        |
# |    iterations           | 19          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010209377 |
# |    clip_fraction        | 0.0848      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.883      |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00635    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.0144      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 17.8        |
# | time/                   |             |
# |    fps                  | 1522        |
# |    iterations           | 20          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008267457 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0185     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0056     |
# |    value_loss           | 0.00297     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 17.8        |
# | time/                   |             |
# |    fps                  | 1521        |
# |    iterations           | 21          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.013790517 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0191     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 0.00317     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 17.8         |
# | time/                   |              |
# |    fps                  | 1522         |
# |    iterations           | 22           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0075158393 |
# |    clip_fraction        | 0.0901       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.728       |
# |    explained_variance   | 0.606        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0044      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00701     |
# |    value_loss           | 0.0251       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 22.3        |
# | time/                   |             |
# |    fps                  | 1521        |
# |    iterations           | 23          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011057759 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.836      |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0212     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00498    |
# |    value_loss           | 0.00505     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 22.3        |
# | time/                   |             |
# |    fps                  | 1521        |
# |    iterations           | 24          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010338104 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00474     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00683    |
# |    value_loss           | 0.0033      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 22.3        |
# | time/                   |             |
# |    fps                  | 1520        |
# |    iterations           | 25          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008246096 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0242     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00582    |
# |    value_loss           | 0.00309     |
# -----------------------------------------
#
# --- Agent 1 Training Metrics ---
# Total Profit: 36.42665547796787
# Cumulative Return: 0.003642665547796787
# Win Rate: 0.7055616139585605
# Profit Factor: 8.510046218223692
# Sharpe Ratio: 0.3907044023572077
# Sortino Ratio: 1.1676623605414231
# Maximum Drawdown: 0.9527547794965479
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 2315 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1842        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008401121 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -2.51       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0144     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.00534     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1716         |
# |    iterations           | 3            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0044789733 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.707        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00328     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00839     |
# |    value_loss           | 0.0116       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 3.78         |
# | time/                   |              |
# |    fps                  | 1666         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0070487424 |
# |    clip_fraction        | 0.0276       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00394      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.01        |
# |    value_loss           | 0.01         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 3.78        |
# | time/                   |             |
# |    fps                  | 1628        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009142084 |
# |    clip_fraction        | 0.056       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0279     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00629    |
# |    value_loss           | 0.00342     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 3.78        |
# | time/                   |             |
# |    fps                  | 1602        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004211815 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.128      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.026       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00552    |
# |    value_loss           | 0.00238     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.64e+03   |
# |    ep_rew_mean          | 3.78       |
# | time/                   |            |
# |    fps                  | 1590       |
# |    iterations           | 7          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00602823 |
# |    clip_fraction        | 0.039      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.291      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0153    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0117    |
# |    value_loss           | 0.0125     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.64e+03   |
# |    ep_rew_mean          | 4.19       |
# | time/                   |            |
# |    fps                  | 1578       |
# |    iterations           | 8          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00717424 |
# |    clip_fraction        | 0.0622     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | -0.157     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0463    |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00988   |
# |    value_loss           | 0.00308    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 4.19        |
# | time/                   |             |
# |    fps                  | 1571        |
# |    iterations           | 9           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010893803 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0136      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.00258     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 4.19        |
# | time/                   |             |
# |    fps                  | 1560        |
# |    iterations           | 10          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007684446 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.15       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0154     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.00183     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 4.19        |
# | time/                   |             |
# |    fps                  | 1545        |
# |    iterations           | 11          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007439101 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.976      |
# |    explained_variance   | -0.0985     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00216     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.0181      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 9.53        |
# | time/                   |             |
# |    fps                  | 1542        |
# |    iterations           | 12          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009525845 |
# |    clip_fraction        | 0.0947      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.00755     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0159     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.00254     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 9.53        |
# | time/                   |             |
# |    fps                  | 1538        |
# |    iterations           | 13          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010680571 |
# |    clip_fraction        | 0.0755      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0393      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00631    |
# |    value_loss           | 0.00308     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 9.53        |
# | time/                   |             |
# |    fps                  | 1535        |
# |    iterations           | 14          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009589013 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | -0.0222     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00538    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00849    |
# |    value_loss           | 0.00348     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.64e+03   |
# |    ep_rew_mean          | 14.9       |
# | time/                   |            |
# |    fps                  | 1533       |
# |    iterations           | 15         |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01118665 |
# |    clip_fraction        | 0.0938     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.879     |
# |    explained_variance   | 0.0593     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0208    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00826   |
# |    value_loss           | 0.0178     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 14.9        |
# | time/                   |             |
# |    fps                  | 1513        |
# |    iterations           | 16          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008910578 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.00342     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 14.9        |
# | time/                   |             |
# |    fps                  | 1512        |
# |    iterations           | 17          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008281574 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | -0.00964    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00515     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00849    |
# |    value_loss           | 0.00274     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 14.9        |
# | time/                   |             |
# |    fps                  | 1511        |
# |    iterations           | 18          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009503298 |
# |    clip_fraction        | 0.0974      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.898      |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0122      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00793    |
# |    value_loss           | 0.0143      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 19.4        |
# | time/                   |             |
# |    fps                  | 1507        |
# |    iterations           | 19          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009787614 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.856      |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00241     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 19.4        |
# | time/                   |             |
# |    fps                  | 1507        |
# |    iterations           | 20          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012210788 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | 0.351       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00646     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00751    |
# |    value_loss           | 0.0033      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 19.4        |
# | time/                   |             |
# |    fps                  | 1506        |
# |    iterations           | 21          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010288918 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | 0.182       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0049     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -2.65e-05   |
# |    value_loss           | 0.00235     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 19.4        |
# | time/                   |             |
# |    fps                  | 1506        |
# |    iterations           | 22          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010422958 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0324      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00378    |
# |    value_loss           | 0.0278      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 24          |
# | time/                   |             |
# |    fps                  | 1505        |
# |    iterations           | 23          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.007230179 |
# |    clip_fraction        | 0.0893      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.827      |
# |    explained_variance   | 0.374       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0238     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00481    |
# |    value_loss           | 0.00359     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 24          |
# | time/                   |             |
# |    fps                  | 1505        |
# |    iterations           | 24          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010926352 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00887     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00429    |
# |    value_loss           | 0.00332     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 24          |
# | time/                   |             |
# |    fps                  | 1505        |
# |    iterations           | 25          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009413103 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.895      |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00484    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00162    |
# |    value_loss           | 0.00242     |
# -----------------------------------------
#
# --- Agent 2 Training Metrics ---
# Total Profit: 39.57476339954337
# Cumulative Return: 0.003957476339954337
# Win Rate: 0.7381776239907728
# Profit Factor: 11.713790079580109
# Sharpe Ratio: 0.4738510664046614
# Sortino Ratio: 1.440238690255034
# Maximum Drawdown: 0.5493486365646802
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 2187 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1641         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0081635695 |
# |    clip_fraction        | 0.0588       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -1.16        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0323      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00963     |
# |    value_loss           | 0.00549      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1578        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017308991 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00636     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00959    |
# |    value_loss           | 0.00769     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 1.26         |
# | time/                   |              |
# |    fps                  | 1552         |
# |    iterations           | 4            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0040781647 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.557        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00992      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00733     |
# |    value_loss           | 0.0213       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 1.26        |
# | time/                   |             |
# |    fps                  | 1544        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007295322 |
# |    clip_fraction        | 0.0849      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0129     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00776    |
# |    value_loss           | 0.00491     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 1.26         |
# | time/                   |              |
# |    fps                  | 1542         |
# |    iterations           | 6            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0040899976 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.0392       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0114      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00419     |
# |    value_loss           | 0.0031       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 1.26        |
# | time/                   |             |
# |    fps                  | 1539        |
# |    iterations           | 7           |
# ...
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 3.8         |
# | time/                   |             |
# |    fps                  | 1446        |
# |    iterations           | 10          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007733892 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.0869     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00953    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.0019      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 3.8         |
# | time/                   |             |
# |    fps                  | 1450        |
# |    iterations           | 11          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008207843 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0047      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 0.0143      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 8.14        |
# | time/                   |             |
# |    fps                  | 1454        |
# |    iterations           | 12          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007510098 |
# |    clip_fraction        | 0.0602      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.142      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000372    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00943    |
# |    value_loss           | 0.00294     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 8.14        |
# | time/                   |             |
# |    fps                  | 1457        |
# |    iterations           | 13          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009749184 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.968      |
# |    explained_variance   | -0.0101     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00354    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00924    |
# |    value_loss           | 0.00279     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 8.14        |
# | time/                   |             |
# |    fps                  | 1459        |
# |    iterations           | 14          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008117005 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0175     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00326     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 14.4        |
# | time/                   |             |
# |    fps                  | 1460        |
# |    iterations           | 15          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.011040696 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0055     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00886    |
# |    value_loss           | 0.0228      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 14.4         |
# | time/                   |              |
# |    fps                  | 1462         |
# |    iterations           | 16           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0072186384 |
# |    clip_fraction        | 0.0664       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.929       |
# |    explained_variance   | 0.233        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00364     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00663     |
# |    value_loss           | 0.00361      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 14.4        |
# | time/                   |             |
# |    fps                  | 1461        |
# |    iterations           | 17          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008688536 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | -0.00355    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0216     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00333    |
# |    value_loss           | 0.00286     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 14.4        |
# | time/                   |             |
# |    fps                  | 1449        |
# |    iterations           | 18          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008501343 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.862      |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0201     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00951    |
# |    value_loss           | 0.0142      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.64e+03   |
# |    ep_rew_mean          | 19.6       |
# | time/                   |            |
# |    fps                  | 1451       |
# |    iterations           | 19         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00987171 |
# |    clip_fraction        | 0.0875     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.885     |
# |    explained_variance   | 0.346      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0178    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0106    |
# |    value_loss           | 0.0127     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.64e+03   |
# |    ep_rew_mean          | 19.6       |
# | time/                   |            |
# |    fps                  | 1449       |
# |    iterations           | 20         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00646632 |
# |    clip_fraction        | 0.0663     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.856     |
# |    explained_variance   | 0.308      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00153   |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.00375   |
# |    value_loss           | 0.00264    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 19.6        |
# | time/                   |             |
# |    fps                  | 1447        |
# |    iterations           | 21          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.011315908 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.81       |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0151     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00449    |
# |    value_loss           | 0.00295     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 19.6        |
# | time/                   |             |
# |    fps                  | 1448        |
# |    iterations           | 22          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008498969 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.742      |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00597    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00863    |
# |    value_loss           | 0.0233      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 24          |
# | time/                   |             |
# |    fps                  | 1433        |
# |    iterations           | 23          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008181175 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.855      |
# |    explained_variance   | 0.0997      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.011      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00974    |
# |    value_loss           | 0.00389     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 24          |
# | time/                   |             |
# |    fps                  | 1433        |
# |    iterations           | 24          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008230092 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00271     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00682    |
# |    value_loss           | 0.0039      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 24          |
# | time/                   |             |
# |    fps                  | 1433        |
# |    iterations           | 25          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008692164 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.776      |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00478     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00251    |
# |    value_loss           | 0.00222     |
# -----------------------------------------
#
# --- Agent 4 Training Metrics ---
# Total Profit: 38.593496610026705
# Cumulative Return: 0.0038593496610026703
# Win Rate: 0.7267144319344934
# Profit Factor: 11.567780237932828
# Sharpe Ratio: 0.4290076494664639
# Sortino Ratio: 2.1303652740043586
# Maximum Drawdown: 0.2630088671552784
#
# === Combined Training Metrics for All Agents (Sharpe Ratio Weighted) ===
# Total Profit: 37.30011668340659
# Cumulative Return: 0.003730011668340659
# Win Rate: 0.7137741233654288
# Profit Factor: 10.072214297890524
# Sharpe Ratio: 0.41151517873402893
# Sortino Ratio: 1.5448409898039082
# Maximum Drawdown: 0.504450378514716
#
# --- Agent 1 Testing Metrics ---
# Total Profit: 24.29914862534133
# Cumulative Return: 0.002429914862534133
# Win Rate: 0.7296
# Profit Factor: 12.518583736931216
# Sharpe Ratio: 0.5423944834260975
# Sortino Ratio: 2.795855277910063
# Maximum Drawdown: 0.10704439205787608
#
# --- Agent 2 Testing Metrics ---
# Total Profit: 24.156477153663218
# Cumulative Return: 0.0024156477153663217
# Win Rate: 0.7258064516129032
# Profit Factor: 12.278696230565718
# Sharpe Ratio: 0.5585357189803988
# Sortino Ratio: 2.696083793452728
# Maximum Drawdown: 0.14126676275295935
#
# --- Agent 3 Testing Metrics ---
# Total Profit: 22.95475064801576
# Cumulative Return: 0.002295475064801576
# Win Rate: 0.6743002544529262
# Profit Factor: 7.753309060257339
# Sharpe Ratio: 0.4563395170797446
# Sortino Ratio: 2.057729093935746
# Maximum Drawdown: 0.12146951924039673
#
# --- Agent 4 Testing Metrics ---
# Total Profit: 24.548963972723868
# Cumulative Return: 0.0024548963972723867
# Win Rate: 0.7153846153846154
# Profit Factor: 10.628681130014039
# Sharpe Ratio: 0.539785819645182
# Sortino Ratio: 2.291989587112551
# Maximum Drawdown: 0.20792079869978508
#
# === Combined Testing Metrics for All Agents (Sharpe Ratio Weighted) ===
# Total Profit: 24.032898044809784
# Cumulative Return: 0.002403289804480978
# Win Rate: 0.7128967921754932
# Profit Factor: 10.931257387600938
# Sharpe Ratio: 0.5272957202767297
# Sortino Ratio: 2.478962555403848
# Maximum Drawdown: 0.14526408836069202

# %%
#multiagent DQN
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import DQN
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'BIDU_TRAINING.csv'
    test_file = 'BIDU_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)
        model = DQN("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=50000)
        models.append(model)

        # Record training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.64e+03 |
# |    ep_rew_mean      | 0.962    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1637     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 30564    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00416  |
# |    n_updates        | 7615     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.64e+03 |
# |    ep_rew_mean      | -4.78    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1587     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 30564    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000289 |
# |    n_updates        | 7615     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.64e+03 |
# |    ep_rew_mean      | -2.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1502     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 30564    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000853 |
# |    n_updates        | 7615     |
# ----------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.64e+03 |
# |    ep_rew_mean      | -9.26    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1557     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 30564    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.02e-05 |
# |    n_updates        | 7615     |
# ----------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 1.7868633853377103
# Cumulative Return: 0.00017868633853377106
# Win Rate: 0.5454545454545454
# Profit Factor: 1.20563228902443
# Sharpe Ratio: 0.04921231981912066
# Sortino Ratio: 0.0677496702635836
# Maximum Drawdown: 1.3273564305358114
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 1.2386528415627254
# Cumulative Return: 0.00012386528415627253
# Win Rate: 0.5301837270341208
# Profit Factor: 1.113169560647436
# Sharpe Ratio: 0.03274622156784421
# Sortino Ratio: 0.04852360631012064
# Maximum Drawdown: 2.618192418390921

# %%
#multiagent a2c
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import A2C
from sklearn.preprocessing import StandardScaler

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment with Modified Reward Structure
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Normalized stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        obs = self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)
        obs -= np.min(obs, axis=0)
        obs /= np.max(obs, axis=0) + 1e-8  # Normalizing to [0,1]
        return obs

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        # Normalize reward and add transaction cost penalty
        reward = (reward / self.initial_balance) - 0.001  # Small penalty for holding a position

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), np.clip(reward, -1, 1), terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'BIDU_TRAINING.csv'
    test_file = 'BIDU_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)
        model = A2C("MlpPolicy", env_train, verbose=1)
        model.learn(total_timesteps=250000)  # Increased timesteps
        models.append(model)

        # Record training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = [model.predict(obs[i])[0] for i, model in enumerate(models)]
        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | time/                 |          |
# |    fps                | 1039     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -27.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0667  |
# |    value_loss         | 0.00539  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 966      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -424     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.0609   |
# |    value_loss         | 0.00482  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1006     |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -307     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0195  |
# |    value_loss         | 0.00122  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1001      |
# |    iterations         | 400       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -0.983    |
# |    explained_variance | -2.71e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 0.00702   |
# |    value_loss         | 0.000712  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 945       |
# |    iterations         | 500       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | -1.13e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 0.000307  |
# |    value_loss         | 0.000989  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 947      |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.866   |
# |    explained_variance | -139     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.00827  |
# |    value_loss         | 0.000246 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 956      |
# |    iterations         | 700      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.724   |
# |    explained_variance | -92.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.00679 |
# |    value_loss         | 0.000155 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 968       |
# |    iterations         | 800       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.936    |
# |    explained_variance | -39.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -0.000384 |
# |    value_loss         | 0.000118  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 969      |
# |    iterations         | 900      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.672   |
# |    explained_variance | -68.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0117  |
# |    value_loss         | 0.00027  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 943      |
# |    iterations         | 1000     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.94    |
# |    explained_variance | -22.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0065   |
# |    value_loss         | 3.64e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 1100     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -938     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.00311 |
# |    value_loss         | 0.000182 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 1200     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -266     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.0122  |
# |    value_loss         | 0.000264 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 934      |
# |    iterations         | 1300     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | -44.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.0163   |
# |    value_loss         | 0.000235 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 928      |
# |    iterations         | 1400     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -290     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.00582 |
# |    value_loss         | 0.000182 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 1500     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | -75.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.0208  |
# |    value_loss         | 0.000439 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 917      |
# |    iterations         | 1600     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -36.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.00224  |
# |    value_loss         | 3.08e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 918      |
# |    iterations         | 1700     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -353     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.00663  |
# |    value_loss         | 4.76e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 918       |
# |    iterations         | 1800      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.868    |
# |    explained_variance | -85.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -0.000926 |
# |    value_loss         | 1.44e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 916      |
# |    iterations         | 1900     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.923   |
# |    explained_variance | -75.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.00146 |
# |    value_loss         | 5.19e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 921      |
# |    iterations         | 2000     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | -71.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.00651 |
# |    value_loss         | 2.9e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 2100     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.537   |
# |    explained_variance | -7.02    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.00438 |
# |    value_loss         | 2.79e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 933       |
# |    iterations         | 2200      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.846    |
# |    explained_variance | -130      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -0.000477 |
# |    value_loss         | 1.57e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 935      |
# |    iterations         | 2300     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -9.2     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.00322 |
# |    value_loss         | 3.75e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 941       |
# |    iterations         | 2400      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.84     |
# |    explained_variance | -34.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -0.000869 |
# |    value_loss         | 5.03e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 943      |
# |    iterations         | 2500     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.652   |
# |    explained_variance | 0.514    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.00321  |
# |    value_loss         | 1.74e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 944      |
# |    iterations         | 2600     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.757   |
# |    explained_variance | -53.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.000569 |
# |    value_loss         | 1.03e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 944      |
# |    iterations         | 2700     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.954   |
# |    explained_variance | -383     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.0029  |
# |    value_loss         | 1.9e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 947      |
# |    iterations         | 2800     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.611   |
# |    explained_variance | -7.69    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.000315 |
# |    value_loss         | 5.52e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 951       |
# |    iterations         | 2900      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -1.05     |
# |    explained_variance | -110      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -0.000783 |
# |    value_loss         | 1.8e-06   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 940      |
# |    iterations         | 3000     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.61    |
# |    explained_variance | -27.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.00208 |
# |    value_loss         | 9.16e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 3100     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.397   |
# |    explained_variance | -6.98    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.00231 |
# |    value_loss         | 7.48e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 940      |
# |    iterations         | 3200     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.428   |
# |    explained_variance | -597     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.000455 |
# |    value_loss         | 1.62e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 944      |
# |    iterations         | 3300     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.314   |
# |    explained_variance | -20.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 3.58e-05 |
# |    value_loss         | 6.16e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 948       |
# |    iterations         | 3400      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.206    |
# |    explained_variance | -122      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -4.92e-05 |
# |    value_loss         | 3.93e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 951       |
# |    iterations         | 3500      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.158    |
# |    explained_variance | -89       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -6.21e-05 |
# |    value_loss         | 7.71e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 953      |
# |    iterations         | 3600     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.994   |
# |    explained_variance | -43.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.00603 |
# |    value_loss         | 6.63e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 954      |
# |    iterations         | 3700     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.154   |
# |    explained_variance | -29.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.0019  |
# |    value_loss         | 4.62e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 953      |
# |    iterations         | 3800     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.107   |
# |    explained_variance | 0.279    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 6.2e-06  |
# |    value_loss         | 2.01e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 934       |
# |    iterations         | 3900      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | -51.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -0.000937 |
# |    value_loss         | 4.07e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 935      |
# |    iterations         | 4000     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.332   |
# |    explained_variance | -638     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.000246 |
# |    value_loss         | 3.46e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 4100     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.39    |
# |    explained_variance | -71.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 7.04e-05 |
# |    value_loss         | 3.99e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 940      |
# |    iterations         | 4200     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.405   |
# |    explained_variance | -32      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 9.86e-08 |
# |    value_loss         | 3.9e-07  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 941       |
# |    iterations         | 4300      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -0.639    |
# |    explained_variance | -1.02e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -5.76e-05 |
# |    value_loss         | 2.02e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 944       |
# |    iterations         | 4400      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -0.962    |
# |    explained_variance | -1.64e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | 0.000975  |
# |    value_loss         | 1.97e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 946      |
# |    iterations         | 4500     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.863   |
# |    explained_variance | -3.19    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.00181  |
# |    value_loss         | 1.12e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 946      |
# |    iterations         | 4600     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.665   |
# |    explained_variance | -25.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.00283  |
# |    value_loss         | 4.24e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 948       |
# |    iterations         | 4700      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -0.215    |
# |    explained_variance | -65.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -8.84e-05 |
# |    value_loss         | 4.65e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 949      |
# |    iterations         | 4800     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.228   |
# |    explained_variance | -5.61    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -8.5e-05 |
# |    value_loss         | 3.6e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 951      |
# |    iterations         | 4900     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.972   |
# |    explained_variance | -116     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.000168 |
# |    value_loss         | 1.5e-06  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 952       |
# |    iterations         | 5000      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -0.321    |
# |    explained_variance | -7.9      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -2.34e-05 |
# |    value_loss         | 2.42e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 953       |
# |    iterations         | 5100      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -0.863    |
# |    explained_variance | -15.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -0.000327 |
# |    value_loss         | 7.01e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 955      |
# |    iterations         | 5200     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.674   |
# |    explained_variance | -71.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.00186  |
# |    value_loss         | 2.95e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 957       |
# |    iterations         | 5300      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.68     |
# |    explained_variance | -75.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -0.000117 |
# |    value_loss         | 5.48e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 958      |
# |    iterations         | 5400     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.48    |
# |    explained_variance | -7.3     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.00222 |
# |    value_loss         | 5.5e-06  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 958      |
# |    iterations         | 5500     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.254   |
# |    explained_variance | -35.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 8.66e-05 |
# |    value_loss         | 1.48e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 960       |
# |    iterations         | 5600      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -0.378    |
# |    explained_variance | -5.31     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -0.000104 |
# |    value_loss         | 1.08e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 957      |
# |    iterations         | 5700     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.978   |
# |    explained_variance | -2.42    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.00129  |
# |    value_loss         | 3.61e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 958      |
# |    iterations         | 5800     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.824   |
# |    explained_variance | -540     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.00116 |
# |    value_loss         | 2.32e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 959      |
# |    iterations         | 5900     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.667   |
# |    explained_variance | -18.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.000598 |
# |    value_loss         | 3.71e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 960      |
# |    iterations         | 6000     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.774   |
# |    explained_variance | -23.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.00229  |
# |    value_loss         | 4.97e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 961      |
# |    iterations         | 6100     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.573   |
# |    explained_variance | -574     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.0049   |
# |    value_loss         | 5.28e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 961      |
# |    iterations         | 6200     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -0.811   |
# |    explained_variance | -100     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.00255 |
# |    value_loss         | 3.21e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 963       |
# |    iterations         | 6300      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -0.89     |
# |    explained_variance | -1.14e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -0.00199  |
# |    value_loss         | 4.85e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 962       |
# |    iterations         | 6400      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -0.563    |
# |    explained_variance | -42.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -0.000256 |
# |    value_loss         | 1.44e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 6500     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.816   |
# |    explained_variance | -5.43    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.00158 |
# |    value_loss         | 1.35e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 964       |
# |    iterations         | 6600      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -0.926    |
# |    explained_variance | -0.252    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -9.44e-05 |
# |    value_loss         | 2.77e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 964      |
# |    iterations         | 6700     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.999   |
# |    explained_variance | -135     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.000703 |
# |    value_loss         | 1.51e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 964      |
# |    iterations         | 6800     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.802   |
# |    explained_variance | -9.05    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.0019   |
# |    value_loss         | 5.92e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 964      |
# |    iterations         | 6900     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.465   |
# |    explained_variance | -2.07    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.000308 |
# |    value_loss         | 8.35e-08 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 964       |
# |    iterations         | 7000      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -0.26     |
# |    explained_variance | -13.6     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -5.67e-05 |
# |    value_loss         | 1.33e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 964      |
# |    iterations         | 7100     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | -37.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.00542 |
# |    value_loss         | 6.58e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 965      |
# |    iterations         | 7200     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.7     |
# |    explained_variance | -32.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | 0.000139 |
# |    value_loss         | 1.34e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 965       |
# |    iterations         | 7300      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -0.357    |
# |    explained_variance | -87.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -8.99e-05 |
# |    value_loss         | 4.58e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 965      |
# |    iterations         | 7400     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.786   |
# |    explained_variance | -8.36    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0.00145 |
# |    value_loss         | 1.01e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 965      |
# |    iterations         | 7500     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.627   |
# |    explained_variance | -2.57    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 0.000331 |
# |    value_loss         | 1.25e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 966       |
# |    iterations         | 7600      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -0.584    |
# |    explained_variance | 0.117     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | -0.000365 |
# |    value_loss         | 3.49e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 966       |
# |    iterations         | 7700      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -0.128    |
# |    explained_variance | -6.72     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -0.000124 |
# |    value_loss         | 2.58e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 967      |
# |    iterations         | 7800     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | -24.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | -0.00135 |
# |    value_loss         | 6.02e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# ...
# |    time_elapsed       | 671      |
# |    total_timesteps    | 239500   |
# | train/                |          |
# |    entropy_loss       | -0.00106 |
# |    explained_variance | -19.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47899    |
# |    policy_loss        | 1.37e-08 |
# |    value_loss         | 5.93e-08 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 356       |
# |    iterations         | 48000     |
# |    time_elapsed       | 673       |
# |    total_timesteps    | 240000    |
# | train/                |           |
# |    entropy_loss       | -0.000917 |
# |    explained_variance | -6.58     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 47999     |
# |    policy_loss        | -3.06e-08 |
# |    value_loss         | 3.03e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 48100    |
# |    time_elapsed       | 674      |
# |    total_timesteps    | 240500   |
# | train/                |          |
# |    entropy_loss       | -0.00111 |
# |    explained_variance | -25.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48099    |
# |    policy_loss        | 2.97e-07 |
# |    value_loss         | 9.17e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 356       |
# |    iterations         | 48200     |
# |    time_elapsed       | 676       |
# |    total_timesteps    | 241000    |
# | train/                |           |
# |    entropy_loss       | -0.00096  |
# |    explained_variance | -34.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48199     |
# |    policy_loss        | -1.42e-08 |
# |    value_loss         | 3.91e-08  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 48300    |
# |    time_elapsed       | 677      |
# |    total_timesteps    | 241500   |
# | train/                |          |
# |    entropy_loss       | -0.00146 |
# |    explained_variance | -2.25    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48299    |
# |    policy_loss        | 1.48e-07 |
# |    value_loss         | 1.26e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 356       |
# |    iterations         | 48400     |
# |    time_elapsed       | 679       |
# |    total_timesteps    | 242000    |
# | train/                |           |
# |    entropy_loss       | -0.000958 |
# |    explained_variance | -4.63     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48399     |
# |    policy_loss        | -7.48e-08 |
# |    value_loss         | 7.91e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 48500    |
# |    time_elapsed       | 680      |
# |    total_timesteps    | 242500   |
# | train/                |          |
# |    entropy_loss       | -0.00115 |
# |    explained_variance | -1.15    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48499    |
# |    policy_loss        | 4.68e-08 |
# |    value_loss         | 2.19e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 356       |
# |    iterations         | 48600     |
# |    time_elapsed       | 682       |
# |    total_timesteps    | 243000    |
# | train/                |           |
# |    entropy_loss       | -0.000969 |
# |    explained_variance | -125      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48599     |
# |    policy_loss        | -1.35e-08 |
# |    value_loss         | 1.52e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 356       |
# |    iterations         | 48700     |
# |    time_elapsed       | 683       |
# |    total_timesteps    | 243500    |
# | train/                |           |
# |    entropy_loss       | -0.00119  |
# |    explained_variance | -55.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48699     |
# |    policy_loss        | -5.89e-08 |
# |    value_loss         | 3.96e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 356       |
# |    iterations         | 48800     |
# |    time_elapsed       | 685       |
# |    total_timesteps    | 244000    |
# | train/                |           |
# |    entropy_loss       | -0.0013   |
# |    explained_variance | -2.02     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48799     |
# |    policy_loss        | -4.77e-08 |
# |    value_loss         | 1.94e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 48900    |
# |    time_elapsed       | 686      |
# |    total_timesteps    | 244500   |
# | train/                |          |
# |    entropy_loss       | -0.00168 |
# |    explained_variance | 0.0417   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48899    |
# |    policy_loss        | 2.24e-07 |
# |    value_loss         | 1.76e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 49000    |
# |    time_elapsed       | 687      |
# |    total_timesteps    | 245000   |
# | train/                |          |
# |    entropy_loss       | -0.00119 |
# |    explained_variance | -36      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48999    |
# |    policy_loss        | 1.02e-07 |
# |    value_loss         | 2.76e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 356       |
# |    iterations         | 49100     |
# |    time_elapsed       | 688       |
# |    total_timesteps    | 245500    |
# | train/                |           |
# |    entropy_loss       | -0.00114  |
# |    explained_variance | -3.59     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49099     |
# |    policy_loss        | -1.76e-07 |
# |    value_loss         | 2.92e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 49200    |
# |    time_elapsed       | 690      |
# |    total_timesteps    | 246000   |
# | train/                |          |
# |    entropy_loss       | -0.00182 |
# |    explained_variance | -9.79    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49199    |
# |    policy_loss        | -6e-08   |
# |    value_loss         | 1.42e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 49300    |
# |    time_elapsed       | 691      |
# |    total_timesteps    | 246500   |
# | train/                |          |
# |    entropy_loss       | -0.0011  |
# |    explained_variance | -86.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49299    |
# |    policy_loss        | 9e-09    |
# |    value_loss         | 2.23e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 49400    |
# |    time_elapsed       | 692      |
# |    total_timesteps    | 247000   |
# | train/                |          |
# |    entropy_loss       | -0.00113 |
# |    explained_variance | -3.61    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49399    |
# |    policy_loss        | 1.71e-07 |
# |    value_loss         | 4.01e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 49500    |
# |    time_elapsed       | 693      |
# |    total_timesteps    | 247500   |
# | train/                |          |
# |    entropy_loss       | -0.00106 |
# |    explained_variance | -0.493   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49499    |
# |    policy_loss        | 2.28e-09 |
# |    value_loss         | 2.66e-08 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 356       |
# |    iterations         | 49600     |
# |    time_elapsed       | 695       |
# |    total_timesteps    | 248000    |
# | train/                |           |
# |    entropy_loss       | -0.00111  |
# |    explained_variance | -31       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49599     |
# |    policy_loss        | -1.46e-07 |
# |    value_loss         | 2.51e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 356       |
# |    iterations         | 49700     |
# |    time_elapsed       | 696       |
# |    total_timesteps    | 248500    |
# | train/                |           |
# |    entropy_loss       | -0.00171  |
# |    explained_variance | -1.99     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49699     |
# |    policy_loss        | -2.95e-07 |
# |    value_loss         | 4.95e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | -7.64    |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 49800    |
# |    time_elapsed       | 697      |
# |    total_timesteps    | 249000   |
# | train/                |          |
# |    entropy_loss       | -0.00103 |
# |    explained_variance | -131     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49799    |
# |    policy_loss        | 6.52e-08 |
# |    value_loss         | 5.18e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 356       |
# |    iterations         | 49900     |
# |    time_elapsed       | 699       |
# |    total_timesteps    | 249500    |
# | train/                |           |
# |    entropy_loss       | -0.000776 |
# |    explained_variance | -1.96     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49899     |
# |    policy_loss        | 1.09e-07  |
# |    value_loss         | 2.8e-06   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | -7.64     |
# | time/                 |           |
# |    fps                | 356       |
# |    iterations         | 50000     |
# |    time_elapsed       | 700       |
# |    total_timesteps    | 250000    |
# | train/                |           |
# |    entropy_loss       | -0.000714 |
# |    explained_variance | -0.771    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49999     |
# |    policy_loss        | -3.08e-08 |
# |    value_loss         | 4.17e-07  |
# -------------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 0
# Cumulative Return: 0
# Win Rate: 0
# Profit Factor: 0
# Sharpe Ratio: 0
# Sortino Ratio: 0
# Maximum Drawdown: 0
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 0.31853665328526404
# Cumulative Return: 3.1853665328526405e-05
# Win Rate: 0.4957264957264957
# Profit Factor: 1.0594323274441146
# Sharpe Ratio: 0.02032771858170557
# Sortino Ratio: 0.03320203103719131
# Maximum Drawdown: 0.9756220880080934
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
#multiagent ensemble
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO, DQN, A2C
from sklearn.preprocessing import StandardScaler
from collections import Counter

# Function to load and normalize data
def load_and_normalize_data(train_file, test_file):
    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)

    df_train['timestamp'] = pd.to_datetime(df_train['timestamp'])
    df_test['timestamp'] = pd.to_datetime(df_test['timestamp'])

    scaler = StandardScaler()
    columns_to_normalize = ['open', 'high', 'low', 'close', 'volume']

    df_train[columns_to_normalize] = scaler.fit_transform(df_train[columns_to_normalize])
    df_test[columns_to_normalize] = scaler.transform(df_test[columns_to_normalize])

    return df_train, df_test, scaler

# Single-Agent Trading Environment
class SingleAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None):
        super(SingleAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.current_step = 0
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # 0 = neutral, 1 = long, -1 = short
        self.trades = []
        self.entry_price = 0
        self.scaler = scaler

        # Action space: hold (0), buy (1), sell (2)
        self.action_space = spaces.Discrete(3)

        # Observation space: Stock prices (open, high, low, close, volume)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(window_size, 5), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.position = 0
        self.balance = self.initial_balance
        self.trades = []
        self.entry_price = 0
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data.iloc[self.current_step:self.current_step + self.window_size][['open', 'high', 'low', 'close', 'volume']].values.astype(np.float32)

    def step(self, action):
        reward = 0
        current_price = self.data.iloc[self.current_step]['close']

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.entry_price = current_price
            elif self.position == -1:
                reward = self.entry_price - current_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.entry_price = current_price
            elif self.position == 1:
                reward = current_price - self.entry_price
                self.balance += reward
                self.trades.append(reward)
                self.position = 0

        self.current_step += 1
        terminated = self.current_step >= len(self.data) - self.window_size
        truncated = False
        return self._get_observation(), reward, terminated, truncated, {}

# Multi-Agent Trading Environment
class MultiAgentEnv(gym.Env):
    def __init__(self, data, window_size=10, initial_balance=10000, scaler=None, num_agents=4):
        super(MultiAgentEnv, self).__init__()
        self.data = data
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.scaler = scaler
        self.num_agents = num_agents
        self.agents = [SingleAgentEnv(data, window_size, initial_balance, scaler) for _ in range(num_agents)]

    def reset(self):
        obs = []
        for agent in self.agents:
            agent_obs, _ = agent.reset()
            obs.append(agent_obs)
        return obs

    def step(self, actions):
        obs, rewards, terminated, truncated, infos = [], [], [], [], []
        for agent, action in zip(self.agents, actions):
            agent_obs, reward, done, truncate, info = agent.step(action)
            obs.append(agent_obs)
            rewards.append(reward)
            terminated.append(done)
            truncated.append(truncate)
            infos.append(info)
        return obs, rewards, any(terminated), any(truncated), infos

# Ensemble model function
def ensemble_predict(actions):
    actions = [int(action) for action in actions]
    action_counts = Counter(actions)
    return action_counts.most_common(1)[0][0]

# Function to calculate metrics for each agent
def calculate_metrics(trades, initial_balance, final_balance):
    total_profit = final_balance - initial_balance
    cumulative_return = (final_balance - initial_balance) / initial_balance
    win_rate = len([trade for trade in trades if trade > 0]) / len(trades) if trades else 0
    gross_profit = sum(trade for trade in trades if trade > 0)
    gross_loss = -sum(trade for trade in trades if trade < 0)
    profit_factor = gross_profit / gross_loss if gross_loss != 0 else np.inf
    returns = np.array(trades)
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    downside_std = np.std([min(0, r) for r in returns])
    sortino_ratio = np.mean(returns) / downside_std if downside_std != 0 else 0
    max_drawdown = np.max(np.maximum.accumulate(np.cumsum(trades)) - np.cumsum(trades)) if trades else 0

    metrics = {
        "Total Profit": total_profit,
        "Cumulative Return": cumulative_return,
        "Win Rate": win_rate,
        "Profit Factor": profit_factor,
        "Sharpe Ratio": sharpe_ratio,
        "Sortino Ratio": sortino_ratio,
        "Maximum Drawdown": max_drawdown
    }
    return metrics

# Sharpe Ratio-weighted aggregation for combined metrics
def aggregate_metrics_sharpe_weighted(metrics_list):
    positive_metrics = [m for m in metrics_list if m["Sharpe Ratio"] > 0]
    total_sharpe = sum(m["Sharpe Ratio"] for m in positive_metrics)
    if total_sharpe == 0:
        return {metric: 0 for metric in metrics_list[0]}
    
    combined_metrics = {
        "Total Profit": sum(m["Total Profit"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Cumulative Return": sum(m["Cumulative Return"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Win Rate": sum(m["Win Rate"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Profit Factor": sum(m["Profit Factor"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sharpe Ratio": sum(m["Sharpe Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Sortino Ratio": sum(m["Sortino Ratio"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
        "Maximum Drawdown": sum(m["Maximum Drawdown"] * m["Sharpe Ratio"] / total_sharpe for m in positive_metrics),
    }
    return combined_metrics

# Train and evaluate each agent
def train_and_evaluate():
    train_file = 'BIDU_TRAINING.csv'
    test_file = 'BIDU_TESTING.csv'
    df_train, df_test, scaler = load_and_normalize_data(train_file, test_file)

    training_metrics = []
    ensemble_models = []

    # Train each agent independently
    for i in range(4):  # 4 agents
        env_train = SingleAgentEnv(df_train, window_size=10, scaler=scaler)

        # Initialize each model
        ppo_model = PPO("MlpPolicy", env_train, verbose=1)
        dqn_model = DQN("MlpPolicy", env_train, verbose=1)
        a2c_model = A2C("MlpPolicy", env_train, verbose=1)

        # Train each model
        ppo_model.learn(total_timesteps=50000)
        dqn_model.learn(total_timesteps=50000)
        a2c_model.learn(total_timesteps=50000)

        # Store trained models in a list
        ensemble_models.append((ppo_model, dqn_model, a2c_model))

        # Calculate training metrics
        training_metrics.append(calculate_metrics(env_train.trades, env_train.initial_balance, env_train.balance))

    combined_training_metrics = aggregate_metrics_sharpe_weighted(training_metrics)
    print("\n=== Combined Training Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_training_metrics.items():
        print(f"{metric}: {value}")

    # Test in the multi-agent environment
    env_test = MultiAgentEnv(df_test, window_size=10, scaler=scaler, num_agents=4)
    obs = env_test.reset()
    done = False
    while not done:
        actions = []
        for i, (ppo_model, dqn_model, a2c_model) in enumerate(ensemble_models):
            ppo_action, _ = ppo_model.predict(obs[i])
            dqn_action, _ = dqn_model.predict(obs[i])
            a2c_action, _ = a2c_model.predict(obs[i])
            final_action = ensemble_predict([ppo_action, dqn_action, a2c_action])
            actions.append(final_action)

        obs, rewards, done, truncated, _ = env_test.step(actions)

    # Calculate and display testing metrics
    testing_metrics = []
    for agent in env_test.agents:
        testing_metrics.append(calculate_metrics(agent.trades, agent.initial_balance, agent.balance))

    combined_testing_metrics = aggregate_metrics_sharpe_weighted(testing_metrics)
    print("\n=== Combined Testing Metrics (Sharpe Ratio Weighted) ===")
    for metric, value in combined_testing_metrics.items():
        print(f"{metric}: {value}")

# Run the training and evaluation
train_and_evaluate()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1348 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 800         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007899505 |
# |    clip_fraction        | 0.0183      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -1.23       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00525     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00462    |
# |    value_loss           | 0.00708     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010359839 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0208      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00816    |
# |    value_loss           | 0.00822     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 2.06        |
# | time/                   |             |
# |    fps                  | 824         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005354221 |
# |    clip_fraction        | 0.0349      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00817    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.0122      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.64e+03   |
# |    ep_rew_mean          | 2.06       |
# | time/                   |            |
# |    fps                  | 848        |
# |    iterations           | 5          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00793694 |
# |    clip_fraction        | 0.0494     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.794      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00118   |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00701   |
# |    value_loss           | 0.0052     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 2.06        |
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006330038 |
# |    clip_fraction        | 0.0409      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.107      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0248     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00561    |
# |    value_loss           | 0.00202     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 2.06        |
# | time/                   |             |
# |    fps                  | 874         |
# |    iterations           | 7           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009086616 |
# |    clip_fraction        | 0.0794      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00357    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.0124      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 3.03         |
# | time/                   |              |
# |    fps                  | 884          |
# |    iterations           | 8            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0056939153 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.646        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0105      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00847     |
# |    value_loss           | 0.00352      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 3.03         |
# | time/                   |              |
# |    fps                  | 893          |
# |    iterations           | 9            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0077261226 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.983       |
# |    explained_variance   | 0.816        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0122      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00723     |
# |    value_loss           | 0.00311      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 3.03        |
# | time/                   |             |
# |    fps                  | 901         |
# |    iterations           | 10          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004240566 |
# |    clip_fraction        | 0.0363      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.0428      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00184     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00429    |
# |    value_loss           | 0.00144     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 3.03        |
# | time/                   |             |
# |    fps                  | 907         |
# |    iterations           | 11          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009254789 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.931      |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0147     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 0.0198      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.64e+03   |
# |    ep_rew_mean          | 7.71       |
# | time/                   |            |
# |    fps                  | 912        |
# |    iterations           | 12         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00708463 |
# |    clip_fraction        | 0.0611     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.993     |
# |    explained_variance   | 0.296      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0031    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0099    |
# |    value_loss           | 0.00284    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 7.71         |
# | time/                   |              |
# |    fps                  | 917          |
# |    iterations           | 13           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0068532135 |
# |    clip_fraction        | 0.0994       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.957       |
# |    explained_variance   | -0.137       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000422     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 0.00273      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 7.71         |
# | time/                   |              |
# |    fps                  | 921          |
# |    iterations           | 14           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0052000536 |
# |    clip_fraction        | 0.0887       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.935       |
# |    explained_variance   | -0.336       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0314      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00796     |
# |    value_loss           | 0.0022       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 924         |
# |    iterations           | 15          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008058691 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.028      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00709    |
# |    value_loss           | 0.0216      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 923         |
# |    iterations           | 16          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008018598 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.927      |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0216     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00801    |
# |    value_loss           | 0.00324     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 17          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007086157 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.935      |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00151    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00516    |
# |    value_loss           | 0.00296     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 13.3         |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 18           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0065825786 |
# |    clip_fraction        | 0.063        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.846       |
# |    explained_variance   | 0.423        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0205      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00754     |
# |    value_loss           | 0.0138       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.64e+03   |
# |    ep_rew_mean          | 19.1       |
# | time/                   |            |
# |    fps                  | 920        |
# |    iterations           | 19         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00975718 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.795     |
# |    explained_variance   | 0.633      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0156    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.00944   |
# |    value_loss           | 0.0108     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 20          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009120966 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.884      |
# |    explained_variance   | 0.517       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000699   |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00652    |
# |    value_loss           | 0.00279     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.64e+03     |
# |    ep_rew_mean          | 19.1         |
# | time/                   |              |
# |    fps                  | 922          |
# |    iterations           | 21           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0075112367 |
# |    clip_fraction        | 0.0935       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.951       |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00791     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00504     |
# |    value_loss           | 0.00356      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 921         |
# |    iterations           | 22          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011598688 |
# |    clip_fraction        | 0.0872      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.709      |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000275    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00282    |
# |    value_loss           | 0.0211      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 24.1        |
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 23          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009773632 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.819      |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.028      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0079     |
# |    value_loss           | 0.00491     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 24.1        |
# | time/                   |             |
# |    fps                  | 919         |
# |    iterations           | 24          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009083912 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.851      |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00463     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00423    |
# |    value_loss           | 0.00311     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.64e+03    |
# |    ep_rew_mean          | 24.1        |
# | time/                   |             |
# |    fps                  | 918         |
# |    iterations           | 25          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.007246944 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.905      |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00335    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000579   |
# |    value_loss           | 0.00208     |
# -----------------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.64e+03 |
# |    ep_rew_mean      | -3.48    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 957      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 30564    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00167  |
# |    n_updates        | 7615     |
# ----------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 701      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -3.87    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0271  |
# |    value_loss         | 0.00113  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 714      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -54      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.0403   |
# |    value_loss         | 0.00226  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 714      |
# |    iterations         | 300      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -24.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.00611 |
# |    value_loss         | 0.000347 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 666      |
# |    iterations         | 400      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | -11.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.0078  |
# |    value_loss         | 0.000191 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 649      |
# |    iterations         | 500      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -1.69    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.00686 |
# |    value_loss         | 0.0001   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 656      |
# |    iterations         | 600      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | 0.00239  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.02     |
# |    value_loss         | 0.000386 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 664      |
# |    iterations         | 700      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -10.4    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.182   |
# |    value_loss         | 0.0909   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 652      |
# |    iterations         | 800      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.833   |
# |    explained_variance | 0.101    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.0426   |
# |    value_loss         | 0.00285  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 642      |
# |    iterations         | 900      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -0.211   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.241    |
# |    value_loss         | 0.0579   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 648      |
# |    iterations         | 1000     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -8.72    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0261  |
# |    value_loss         | 0.000537 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 650      |
# |    iterations         | 1100     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -24.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.00203 |
# |    value_loss         | 2.47e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 653      |
# |    iterations         | 1200     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -5.09    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.0466   |
# |    value_loss         | 0.00195  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 649      |
# |    iterations         | 1300     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -18.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.0164  |
# |    value_loss         | 0.000316 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 639      |
# |    iterations         | 1400     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -1.8     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.0575   |
# |    value_loss         | 0.00281  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 635      |
# |    iterations         | 1500     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -0.417   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.00799  |
# |    value_loss         | 0.000286 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 638      |
# |    iterations         | 1600     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.826   |
# |    explained_variance | -7.45    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.00235  |
# |    value_loss         | 6.21e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 641      |
# |    iterations         | 1700     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.991   |
# |    explained_variance | -0.154   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.0169   |
# |    value_loss         | 0.000411 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 645      |
# |    iterations         | 1800     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -0.0173  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.0016   |
# |    value_loss         | 1.52e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 641      |
# |    iterations         | 1900     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -1.76    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.00549  |
# |    value_loss         | 3.08e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 643      |
# |    iterations         | 2000     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.829   |
# |    explained_variance | -0.322   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0167   |
# |    value_loss         | 0.000184 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 648      |
# |    iterations         | 2100     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.751   |
# |    explained_variance | 0.165    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.0746  |
# |    value_loss         | 0.00504  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 649      |
# |    iterations         | 2200     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.918   |
# |    explained_variance | -0.017   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.0641  |
# |    value_loss         | 0.00201  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 651      |
# |    iterations         | 2300     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.875   |
# |    explained_variance | -0.213   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.0278   |
# |    value_loss         | 0.0017   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 652      |
# |    iterations         | 2400     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.949   |
# |    explained_variance | -0.0119  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.0225  |
# |    value_loss         | 0.00722  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 654      |
# |    iterations         | 2500     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.728   |
# |    explained_variance | -1.15    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.00559 |
# |    value_loss         | 5.93e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 654      |
# |    iterations         | 2600     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.877   |
# |    explained_variance | -11.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.000666 |
# |    value_loss         | 2.27e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 654      |
# |    iterations         | 2700     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -0.22    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.0317  |
# |    value_loss         | 0.00249  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 654      |
# |    iterations         | 2800     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.959   |
# |    explained_variance | -31      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.0355  |
# |    value_loss         | 0.00518  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 656      |
# |    iterations         | 2900     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.907   |
# |    explained_variance | 0.195    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.0441   |
# |    value_loss         | 0.00191  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | 5.42      |
# | time/                 |           |
# |    fps                | 656       |
# |    iterations         | 3000      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -1.02     |
# |    explained_variance | -3.63e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 0.0724    |
# |    value_loss         | 0.00411   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 3.33     |
# | time/                 |          |
# |    fps                | 655      |
# |    iterations         | 3100     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.986   |
# |    explained_variance | -2.18    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.00455  |
# |    value_loss         | 4.57e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 3.33     |
# | time/                 |          |
# |    fps                | 657      |
# |    iterations         | 3200     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.742   |
# |    explained_variance | 0.929    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.000857 |
# |    value_loss         | 2.51e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 3.33     |
# | time/                 |          |
# |    fps                | 657      |
# |    iterations         | 3300     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.717   |
# |    explained_variance | -0.977   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.00083  |
# |    value_loss         | 2.43e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 3.33     |
# | time/                 |          |
# |    fps                | 655      |
# |    iterations         | 3400     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.916   |
# |    explained_variance | -2.55    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.00154  |
# |    value_loss         | 2.45e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 3.33     |
# | time/                 |          |
# |    fps                | 656      |
# |    iterations         | 3500     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.831   |
# |    explained_variance | -0.059   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.00134  |
# |    value_loss         | 4.11e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | 3.33      |
# | time/                 |           |
# |    fps                | 656       |
# |    iterations         | 3600      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.751    |
# |    explained_variance | -8.26     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -0.000609 |
# |    value_loss         | 3.45e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 3.33     |
# | time/                 |          |
# |    fps                | 658      |
# |    iterations         | 3700     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.887   |
# |    explained_variance | -0.16    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.0416   |
# |    value_loss         | 0.0046   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 3.33     |
# | time/                 |          |
# |    fps                | 660      |
# |    iterations         | 3800     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.798   |
# |    explained_variance | -0.338   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.00241  |
# |    value_loss         | 4.9e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 3.33     |
# | time/                 |          |
# |    fps                | 661      |
# |    iterations         | 3900     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.849   |
# |    explained_variance | 0.426    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.212   |
# |    value_loss         | 0.13     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 3.33     |
# | time/                 |          |
# |    fps                | 663      |
# |    iterations         | 4000     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.792   |
# |    explained_variance | -0.507   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.00213  |
# |    value_loss         | 2.04e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 3.33     |
# | time/                 |          |
# |    fps                | 664      |
# |    iterations         | 4100     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.721   |
# |    explained_variance | -0.0859  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.0177   |
# |    value_loss         | 0.000636 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 3.33     |
# | time/                 |          |
# |    fps                | 663      |
# |    iterations         | 4200     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.751   |
# |    explained_variance | 0.628    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.00201  |
# |    value_loss         | 0.000103 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 3.33     |
# | time/                 |          |
# |    fps                | 665      |
# |    iterations         | 4300     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.729   |
# |    explained_variance | -2.77    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.0363  |
# |    value_loss         | 0.00165  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 3.33     |
# | time/                 |          |
# |    fps                | 665      |
# |    iterations         | 4400     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.925   |
# |    explained_variance | -18.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.00129  |
# ...
# |    policy_loss        | -1.9e-06 |
# |    value_loss         | 3.88e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | 1.26      |
# | time/                 |           |
# |    fps                | 659       |
# |    iterations         | 7700      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -0.00846  |
# |    explained_variance | -114      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -1.27e-06 |
# |    value_loss         | 1.87e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 1.26     |
# | time/                 |          |
# |    fps                | 659      |
# |    iterations         | 7800     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -0.0101  |
# |    explained_variance | -12.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | 1.51e-07 |
# |    value_loss         | 8.31e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 1.26     |
# | time/                 |          |
# |    fps                | 660      |
# |    iterations         | 7900     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -0.00668 |
# |    explained_variance | -17.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | 6.6e-07  |
# |    value_loss         | 8.78e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | 1.26      |
# | time/                 |           |
# |    fps                | 659       |
# |    iterations         | 8000      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -0.00849  |
# |    explained_variance | -9.81     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | -2.62e-06 |
# |    value_loss         | 9.39e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 1.26     |
# | time/                 |          |
# |    fps                | 659      |
# |    iterations         | 8100     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -0.252   |
# |    explained_variance | -20.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | -0.00132 |
# |    value_loss         | 5.69e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | 1.26      |
# | time/                 |           |
# |    fps                | 660       |
# |    iterations         | 8200      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -0.0062   |
# |    explained_variance | -15.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8199      |
# |    policy_loss        | -1.32e-07 |
# |    value_loss         | 8.89e-08  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 1.26     |
# | time/                 |          |
# |    fps                | 660      |
# |    iterations         | 8300     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 41500    |
# | train/                |          |
# |    entropy_loss       | -0.012   |
# |    explained_variance | -339     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8299     |
# |    policy_loss        | 8.95e-07 |
# |    value_loss         | 4.89e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 1.26     |
# | time/                 |          |
# |    fps                | 661      |
# |    iterations         | 8400     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.418   |
# |    explained_variance | -3.75    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | 0.00139  |
# |    value_loss         | 7.45e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 1.26     |
# | time/                 |          |
# |    fps                | 662      |
# |    iterations         | 8500     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 42500    |
# | train/                |          |
# |    entropy_loss       | -0.462   |
# |    explained_variance | -19.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8499     |
# |    policy_loss        | 0.000524 |
# |    value_loss         | 1.94e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | 1.26      |
# | time/                 |           |
# |    fps                | 662       |
# |    iterations         | 8600      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -0.638    |
# |    explained_variance | -153      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8599      |
# |    policy_loss        | -0.000311 |
# |    value_loss         | 5.32e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | 1.26      |
# | time/                 |           |
# |    fps                | 663       |
# |    iterations         | 8700      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -0.646    |
# |    explained_variance | -29.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -3.74e-05 |
# |    value_loss         | 1.18e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | 1.26      |
# | time/                 |           |
# |    fps                | 663       |
# |    iterations         | 8800      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -0.762    |
# |    explained_variance | -31.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -0.000549 |
# |    value_loss         | 2.15e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | 1.26      |
# | time/                 |           |
# |    fps                | 664       |
# |    iterations         | 8900      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -0.126    |
# |    explained_variance | -1.46e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | 0.000257  |
# |    value_loss         | 6.78e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 1.26     |
# | time/                 |          |
# |    fps                | 664      |
# |    iterations         | 9000     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 45000    |
# | train/                |          |
# |    entropy_loss       | -0.176   |
# |    explained_variance | -0.926   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8999     |
# |    policy_loss        | -0.0445  |
# |    value_loss         | 0.002    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | 1.26      |
# | time/                 |           |
# |    fps                | 665       |
# |    iterations         | 9100      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -0.157    |
# |    explained_variance | -2.2e+03  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | -0.000228 |
# |    value_loss         | 2.3e-05   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 1.19     |
# | time/                 |          |
# |    fps                | 665      |
# |    iterations         | 9200     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.0263  |
# |    explained_variance | -9       |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9199     |
# |    policy_loss        | 7.01e-06 |
# |    value_loss         | 5.13e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 1.19     |
# | time/                 |          |
# |    fps                | 663      |
# |    iterations         | 9300     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 46500    |
# | train/                |          |
# |    entropy_loss       | -0.00749 |
# |    explained_variance | -11.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9299     |
# |    policy_loss        | 3.01e-07 |
# |    value_loss         | 3.29e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 1.19     |
# | time/                 |          |
# |    fps                | 662      |
# |    iterations         | 9400     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 47000    |
# | train/                |          |
# |    entropy_loss       | -0.00685 |
# |    explained_variance | -17.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9399     |
# |    policy_loss        | 1.26e-07 |
# |    value_loss         | 4.23e-08 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | 1.19      |
# | time/                 |           |
# |    fps                | 663       |
# |    iterations         | 9500      |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -0.00707  |
# |    explained_variance | -100      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9499      |
# |    policy_loss        | -6.39e-08 |
# |    value_loss         | 3.84e-08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | 1.19      |
# | time/                 |           |
# |    fps                | 663       |
# |    iterations         | 9600      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -0.00466  |
# |    explained_variance | -2.94     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9599      |
# |    policy_loss        | -7.15e-08 |
# |    value_loss         | 2.75e-08  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 1.19     |
# | time/                 |          |
# |    fps                | 663      |
# |    iterations         | 9700     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 48500    |
# | train/                |          |
# |    entropy_loss       | -0.00652 |
# |    explained_variance | -3.64    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9699     |
# |    policy_loss        | 4.94e-08 |
# |    value_loss         | 1.18e-08 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 7.64e+03  |
# |    ep_rew_mean        | 1.19      |
# | time/                 |           |
# |    fps                | 664       |
# |    iterations         | 9800      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -0.00947  |
# |    explained_variance | -5.42     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9799      |
# |    policy_loss        | -3.54e-07 |
# |    value_loss         | 7.58e-08  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 1.19     |
# | time/                 |          |
# |    fps                | 663      |
# |    iterations         | 9900     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 49500    |
# | train/                |          |
# |    entropy_loss       | -0.642   |
# |    explained_variance | -10.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9899     |
# |    policy_loss        | 0.00226  |
# |    value_loss         | 2.74e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.64e+03 |
# |    ep_rew_mean        | 1.19     |
# | time/                 |          |
# |    fps                | 663      |
# |    iterations         | 10000    |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | -13.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9999     |
# |    policy_loss        | 7.04e-05 |
# |    value_loss         | 4.54e-08 |
# ------------------------------------
#
# === Combined Training Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 0.3798513311525122
# Cumulative Return: 3.798513311525121e-05
# Win Rate: 0.5895721100014885
# Profit Factor: 1.419378617119874
# Sharpe Ratio: 0.12002814464934952
# Sortino Ratio: 0.2523916000230979
# Maximum Drawdown: 0.6032351844258834
#
# === Combined Testing Metrics (Sharpe Ratio Weighted) ===
# Total Profit: 20.567149392218006
# Cumulative Return: 0.002056714939221801
# Win Rate: 0.7450560816192503
# Profit Factor: 11.711233037064817
# Sharpe Ratio: 0.5846343629132261
# Sortino Ratio: 3.800663871941952
# Maximum Drawdown: 0.2243464057412414
